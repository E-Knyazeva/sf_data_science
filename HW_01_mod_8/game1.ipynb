# %% [markdown]
# # Игра Угадай число

# %%
from game1_v2 import score_game
from game1_v2 import random_predict

# %% [markdown]
# ## Угадываем рандомно

# %%
score_game(random_predict)
# Out:
# Алгоритм рассчитал число 38 за 7 попыток.
# Алгоритм рассчитал число 13 за 7 попыток.
# Алгоритм рассчитал число 73 за 7 попыток.
# Алгоритм рассчитал число 10 за 8 попыток.
# Алгоритм рассчитал число 76 за 8 попыток.
# Алгоритм рассчитал число 6 за 3 попыток.
# Алгоритм рассчитал число 80 за 4 попыток.
# Алгоритм рассчитал число 65 за 8 попыток.
# Алгоритм рассчитал число 17 за 5 попыток.
# Алгоритм рассчитал число 2 за 2 попыток.
# Алгоритм рассчитал число 77 за 7 попыток.
# Алгоритм рассчитал число 72 за 6 попыток.
# Алгоритм рассчитал число 7 за 2 попыток.
# Алгоритм рассчитал число 26 за 5 попыток.
# Алгоритм рассчитал число 51 за 6 попыток.
# Алгоритм рассчитал число 21 за 7 попыток.
# Алгоритм рассчитал число 19 за 8 попыток.
# Алгоритм рассчитал число 85 за 3 попыток.
# Алгоритм рассчитал число 12 за 7 попыток.
# Алгоритм рассчитал число 29 за 7 попыток.
# Алгоритм рассчитал число 30 за 6 попыток.
# Алгоритм рассчитал число 15 за 6 попыток.
# ...
